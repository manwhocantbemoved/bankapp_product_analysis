# %%
import pandas as pd

df = pd.read_csv("google_play_reviews.csv")
df
# Out:
#                                    reviewId       userName  \
# 0      bfb0b4a9-6b7d-41c7-9fe0-54c8eacc20bc  A Google user
# 1      59c2b22c-693a-4599-b39c-02afad058f71  A Google user
# 2      06881c1e-0160-42d5-a441-13f40a689e8a  A Google user
# 3      8549e4d0-5ead-4c40-8d6d-5a16b5d6e3c5  A Google user
# 4      92478c30-4ebd-4c14-b2a1-1b4faa322743  A Google user
# ...                                     ...            ...
# 11995  a7b49f52-01bb-43cc-924b-5a87b2a25356  A Google user
# 11996  7be96faf-97b0-42f4-ad9a-52577662096a  A Google user
# 11997  5b38a5d4-2339-4201-b490-024caf66627f  A Google user
# 11998  8e5edc59-b0a4-42ba-ab98-2f410c3f7591  A Google user
# 11999  f0ad3a8e-da46-49e3-9d92-84b3880904e1  A Google user
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/EGemoI2N...
# 1      https://play-lh.googleusercontent.com/EGemoI2N...
# 2      https://play-lh.googleusercontent.com/EGemoI2N...
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              12000 non-null  str
#  1   userName              12000 non-null  str
#  2   userImage             12000 non-null  str
#  3   content               12000 non-null  str
#  4   score                 12000 non-null  int64
#  5   thumbsUpCount         12000 non-null  int64
#  6   reviewCreatedVersion  10430 non-null  str
#  7   at                    12000 non-null  str
#  8   replyContent          5744 non-null   str
#  9   repliedAt             5744 non-null   str
#  10  appVersion            10430 non-null  str
#  11  bank                  12000 non-null  str
# dtypes: int64(2), str(10)
# memory usage: 1.1 MB

# %%
df.isna().sum()
# Out:
# reviewId                   0
# userName                   0
# userImage                  0
# content                    0
# score                      0
# thumbsUpCount              0
# reviewCreatedVersion    1570
# at                         0
# replyContent            6256
# repliedAt               6256
# appVersion              1570
# bank                       0
# dtype: int64

# %%
df_clean = df

# %%
df_clean.drop(columns=["replyContent"], inplace=True)

# %%
df_clean.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              12000 non-null  str
#  1   userName              12000 non-null  str
#  2   userImage             12000 non-null  str
#  3   content               12000 non-null  str
#  4   score                 12000 non-null  int64
#  5   thumbsUpCount         12000 non-null  int64
#  6   reviewCreatedVersion  10430 non-null  str
#  7   at                    12000 non-null  str
#  8   repliedAt             5744 non-null   str
#  9   appVersion            10430 non-null  str
#  10  bank                  12000 non-null  str
# dtypes: int64(2), str(9)
# memory usage: 1.0 MB

# %%
df_clean.drop(columns=["repliedAt"], inplace=True)

# %%
df_clean.isna().sum()
# Out:
# reviewId                   0
# userName                   0
# userImage                  0
# content                    0
# score                      0
# thumbsUpCount              0
# reviewCreatedVersion    1570
# at                         0
# appVersion              1570
# bank                       0
# dtype: int64

# %%
df['at']
# Out:
# 0        2026-09-08 06:38:04
# 1        2026-09-08 02:33:57
# 2        2026-09-08 02:33:30
# 3        2026-09-08 01:13:14
# 4        2026-09-08 00:12:14
#                 ...
# 11995    2025-11-24 17:06:55
# 11996    2025-11-24 15:07:53
# 11997    2025-11-24 14:00:06
# 11998    2025-11-24 13:27:04
# 11999    2025-11-24 12:50:31
# Name: at, Length: 12000, dtype: str

# %%
df_clean["at"] = pd.to_datetime(df_clean["at"])

# %%
df_clean['at']
# Out:
# 0        2026-09-08 06:38:04
# 1        2026-09-08 02:33:57
# 2        2026-09-08 02:33:30
# 3        2026-09-08 01:13:14
# 4        2026-09-08 00:12:14
#                 ...
# 11995    2025-11-24 17:06:55
# 11996    2025-11-24 15:07:53
# 11997    2025-11-24 14:00:06
# 11998    2025-11-24 13:27:04
# 11999    2025-11-24 12:50:31
# Name: at, Length: 12000, dtype: str

# %%
df_clean.info()
print(df_clean["thumbsUpCount"].unique())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   reviewId       12000 non-null  str
#  1   content        12000 non-null  str
#  2   score          12000 non-null  int64
#  3   thumbsUpCount  12000 non-null  int64
#  4   at             12000 non-null  datetime64[us]
#  5   appVersion     10430 non-null  str
#  6   bank           12000 non-null  str
# dtypes: datetime64[us](1), int64(2), str(4)
# memory usage: 656.4 KB
# [  0   1   2   3   7   4   6  14   5  11  12  15  20  17  25   8  22  18
#    9  24  26  37  21  23  13  31  32  40  46  84  71  10  19 121  27 233
#  105 328  28  30  95  38  54  35 155]

# %%
df_clean.drop(columns=["userName"], inplace=True)

# %%
print(df_clean[df_clean["bank"] != "Metrobank"]["bank"].head(50))

# %%
print(df_clean["reviewId"].unique())
# Out:
# <StringArray>
# ['bfb0b4a9-6b7d-41c7-9fe0-54c8eacc20bc',
#  '59c2b22c-693a-4599-b39c-02afad058f71',
#  '06881c1e-0160-42d5-a441-13f40a689e8a',
#  '8549e4d0-5ead-4c40-8d6d-5a16b5d6e3c5',
#  '92478c30-4ebd-4c14-b2a1-1b4faa322743',
#  '7adc3030-c97d-46e2-b35c-7f3ae2dc50ed',
#  'e273b2ea-00b6-4050-8af4-53dc8da742cf',
#  'fe6bafb9-8bda-46ad-8952-b949e750db82',
#  'd2bf3d4a-096a-4144-8662-f449c385e496',
#  'cc2cd6e3-bae7-4032-bb45-7744254b24bc',
#  ...
#  'a9026b8d-5f9a-401b-9b37-881217f848a4',
#  'f17dc1af-aab3-4308-950a-563b5aea9ffc',
#  '8571b1f0-43cb-4982-9e14-4c72eb66563f',
#  'dd18ce08-de51-4d8d-9969-f0b50ee7372d',
#  '15ac9f8b-af88-4fca-bd1f-c3e95c694c79',
#  'a7b49f52-01bb-43cc-924b-5a87b2a25356',
#  '7be96faf-97b0-42f4-ad9a-52577662096a',
#  '5b38a5d4-2339-4201-b490-024caf66627f',
#  '8e5edc59-b0a4-42ba-ab98-2f410c3f7591',
#  'f0ad3a8e-da46-49e3-9d92-84b3880904e1']
# Length: 12000, dtype: str

# %%
print(df_clean.isna().sum())
# Out:
# reviewId                   0
# content                    0
# score                      0
# thumbsUpCount              0
# reviewCreatedVersion    1570
# at                         0
# appVersion              1570
# bank                       0
# dtype: int64

# %%
(df_clean["reviewCreatedVersion"] == df_clean["appVersion"]).value_counts()
# Out:
# True     10430
# False     1570
# Name: count, dtype: int64

# %%
df_clean.drop(columns=["reviewCreatedVersion"], inplace=True)

# %%
df_clean[df_clean["score"] > 3].head(20)
# Out:
#                                  reviewId  \
# 13   652b5cf1-0ee1-45e1-bb33-8b6d2dd93cea
# 16   3bb0d8e3-fa82-442e-9342-7b16fbc81c7e
# 29   391411e0-6031-4422-bf96-6805502224b3
# 32   c94575dd-bf3a-4082-b58b-c0d34165956f
# 42   1ed7bdd7-72ff-4b4e-8802-07722c9faf89
# 66   b57c1287-e676-4d88-b97c-e36f5e949f94
# 68   16b7056d-7a5d-4efa-a3ea-c20ec6e4fb80
# 70   8835c4ff-c889-4093-a42d-1f2d69f09a36
# 78   98c6c619-2fa8-40ea-b77f-6071f24dba98
# 82   1601c66e-5cc0-44e3-bccb-403a3ecedf4e
# 105  87e16ee4-734b-431c-8608-5490a9eebfdd
# 106  76abc0d9-5417-4e4b-b6f9-e060bbdc771d
# 115  70996c72-c737-49e7-9207-c72d668054cb
# 134  c1167a25-a146-472e-ada5-971bd1fb84ea
# 150  15d09fee-8aa9-4be5-bf8f-5ebd2dc926e9
# 160  b98b3ac7-1fd4-4a01-a9d8-38ae6791430c
# 196  d10b629c-2551-432b-919a-d4a48b63de46
# 295  e9a5ded2-fc15-4d84-adc9-a994a7ca5ebd
# 298  40c9370e-27e8-4c37-acf9-d633bd59df03
# 305  b9e7eaa5-4223-488c-a351-f58d13214969
#
# ...

# %%
df_clean.to_csv("cleandataset.csv", index=True)

# %%
df_clean["Date"] = df_clean["at"].dt.date
df_clean["Time"] = df_clean["at"].dt.time

# %%
df_clean
# Out:
#                                    reviewId  \
# 0      bfb0b4a9-6b7d-41c7-9fe0-54c8eacc20bc
# 1      59c2b22c-693a-4599-b39c-02afad058f71
# 2      06881c1e-0160-42d5-a441-13f40a689e8a
# 3      8549e4d0-5ead-4c40-8d6d-5a16b5d6e3c5
# 4      92478c30-4ebd-4c14-b2a1-1b4faa322743
# ...                                     ...
# 11995  a7b49f52-01bb-43cc-924b-5a87b2a25356
# 11996  7be96faf-97b0-42f4-ad9a-52577662096a
# 11997  5b38a5d4-2339-4201-b490-024caf66627f
# 11998  8e5edc59-b0a4-42ba-ab98-2f410c3f7591
# 11999  f0ad3a8e-da46-49e3-9d92-84b3880904e1
#
#                                                  content  score  \
# 0      improve the app compare to other bank it was e...      1
# 1          always "something went wrong" in transactions      1
# 2      Several restart, uninstall and reinstalling th...      1
# 3                     Xiaomi white screen issue till now      1
# 4      NOT RESPOND AT ALL!!!!! after you update and a...      1
# ...

# %%
df_clean.fillna({'appVersion' : 'unknown'}, inplace=True)
# Out:
#                                    reviewId  \
# 0      bfb0b4a9-6b7d-41c7-9fe0-54c8eacc20bc
# 1      59c2b22c-693a-4599-b39c-02afad058f71
# 2      06881c1e-0160-42d5-a441-13f40a689e8a
# 3      8549e4d0-5ead-4c40-8d6d-5a16b5d6e3c5
# 4      92478c30-4ebd-4c14-b2a1-1b4faa322743
# ...                                     ...
# 11995  a7b49f52-01bb-43cc-924b-5a87b2a25356
# 11996  7be96faf-97b0-42f4-ad9a-52577662096a
# 11997  5b38a5d4-2339-4201-b490-024caf66627f
# 11998  8e5edc59-b0a4-42ba-ab98-2f410c3f7591
# 11999  f0ad3a8e-da46-49e3-9d92-84b3880904e1
#
#                                                  content  score  \
# 0      improve the app compare to other bank it was e...      1
# 1          always "something went wrong" in transactions      1
# 2      Several restart, uninstall and reinstalling th...      1
# 3                     Xiaomi white screen issue till now      1
# 4      NOT RESPOND AT ALL!!!!! after you update and a...      1
# ...

# %%
df_clean.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   reviewId       12000 non-null  str
#  1   content        12000 non-null  str
#  2   score          12000 non-null  int64
#  3   thumbsUpCount  12000 non-null  int64
#  4   appVersion     12000 non-null  str
#  5   bank           12000 non-null  str
#  6   Date           12000 non-null  object
# dtypes: int64(2), object(1), str(4)
# memory usage: 656.4+ KB
